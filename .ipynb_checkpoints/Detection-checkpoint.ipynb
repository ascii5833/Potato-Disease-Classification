# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, confusion_matrix,roc_curve, roc_auc_score
# %matplotlib inline

# %% [markdown]
# <h2>Notebook to classify whether the tomato leaf images are diseased or not, based on glcm features</h2>

# %%
#read detection dataframe
df=pd.read_csv("Data/train_detection.csv")
df.head()
# Out:
#    Autocorrelation  Contrast  Correlation  Correlation.1  Cluster Prominence  \
# 0         4.937605  0.423813     0.894121       0.894121          231.248614
# 1         2.551722  0.259480     0.871947       0.871947          202.027005
# 2         6.206039  0.618669     0.881609       0.881609          290.479083
# 3         1.885596  0.194235     0.828962       0.828962           82.500028
# 4         4.790395  0.481035     0.890599       0.890599          343.387103
#
#    Cluster Shade  Dissimilarity    Energy   Entropy   Homogeneity  ...  \
# 0      32.252113       0.232233  0.518499  1.458699      0.907496  ...
# 1      25.453599       0.109989  0.813569  0.644821      0.961702  ...
# 2      38.493259       0.287417  0.465086  1.622099      0.893214  ...
# 3      12.126492       0.090015  0.849845  0.524957      0.967822  ...
# 4      44.837110       0.210380  0.629436  1.159005      0.925256  ...
#
#    Sum average  Sum variance  Sum entropy  Difference variance  \
# ...

# %%
#extract the target feature
y=df['class']
X=df.drop(labels="class",axis=1)
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: class, dtype: int64

# %%
X.head()
# Out:
#    Autocorrelation  Contrast  Correlation  Correlation.1  Cluster Prominence  \
# 0         4.937605  0.423813     0.894121       0.894121          231.248614
# 1         2.551722  0.259480     0.871947       0.871947          202.027005
# 2         6.206039  0.618669     0.881609       0.881609          290.479083
# 3         1.885596  0.194235     0.828962       0.828962           82.500028
# 4         4.790395  0.481035     0.890599       0.890599          343.387103
#
#    Cluster Shade  Dissimilarity    Energy   Entropy   Homogeneity  ...  \
# 0      32.252113       0.232233  0.518499  1.458699      0.907496  ...
# 1      25.453599       0.109989  0.813569  0.644821      0.961702  ...
# 2      38.493259       0.287417  0.465086  1.622099      0.893214  ...
# 3      12.126492       0.090015  0.849845  0.524957      0.967822  ...
# 4      44.837110       0.210380  0.629436  1.159005      0.925256  ...
#
#    Sum of sqaures: Variance  Sum average  Sum variance  Sum entropy  \
# ...

# %%
#divide data into training and validation data
X_train,X_val,y_train,y_val=train_test_split(X,y,test_size=0.2,stratify=df['class'],random_state=1)#equal classes in train and test
X_train.head()
# Out:
#     Autocorrelation  Contrast  Correlation  Correlation.1  Cluster Prominence  \
# 58         1.465746  0.054413     0.918084       0.918084          108.015921
# 74         2.623449  0.226382     0.890990       0.890990          228.996836
# 90         4.602481  0.274810     0.881824       0.881824           38.152597
# 35         1.500289  0.099062     0.856669       0.856669           67.960771
# 86         7.639327  0.281553     0.942850       0.942850          137.504610
#
#     Cluster Shade  Dissimilarity    Energy   Entropy   Homogeneity  ...  \
# 58      11.264020       0.021992  0.957068  0.175747      0.992297  ...
# 74      27.330417       0.094645  0.795433  0.689470      0.966033  ...
# 90       5.857354       0.225882  0.317922  1.692087      0.894599  ...
# 35       8.949488       0.039946  0.934587  0.248797      0.986619  ...
# 86      14.544878       0.219284  0.344013  1.672913      0.899347  ...
#
# ...

# %% [markdown]
# <h2>Feature Normalization</h2>

# %%
scaler=StandardScaler()
columns=X_train.columns
X_train=pd.DataFrame(scaler.fit_transform(X_train),columns=columns)
X_val=pd.DataFrame(scaler.transform(X_val),columns=columns)
X_train.head()
# Out:
#    Autocorrelation  Contrast  Correlation  Correlation.1  Cluster Prominence  \
# 0        -1.078776 -1.696374     0.521909       0.521909           -0.855082
# 1        -0.686131 -0.416382    -0.135460      -0.135460            0.646018
# 2        -0.014924 -0.055927    -0.357847      -0.357847           -1.721928
# 3        -1.067061 -1.364048    -0.968168      -0.968168           -1.352076
# 4         1.015050 -0.005733     1.122783       1.122783           -0.489194
#
#    Cluster Shade  Dissimilarity    Energy   Entropy   Homogeneity  ...  \
# 0      -0.937949      -1.527562  1.345081 -1.455971      1.406307  ...
# 1       0.687758      -0.760177  0.705684 -0.663910      0.802771  ...
# 2      -1.485033       0.625990 -1.183266  0.881931     -0.838781  ...
# 3      -1.172150      -1.337921  1.256151 -1.343342      1.275817  ...
# 4      -0.605970       0.556298 -1.080052  0.852369     -0.729683  ...
#
#    Sum of sqaures: Variance  Sum average  Sum variance  Sum entropy  \
# ...

# %%
print(y_train.value_counts())
print(y_val.value_counts())
y_train.head()
# Out:
# 1    64
# 0    32
# Name: class, dtype: int64
# 1    16
# 0     8
# Name: class, dtype: int64
# 58    1
# 74    1
# 90    0
# 35    1
# 86    0
# Name: class, dtype: int64

# %%
#choosing different C values
C=[0.01,0.03,0.1,0.3,1,3,10,30,100]
sigma=[0.01,0.03,0.1,0.3,1,3,10,30,100]

# %%
#predict score function
def predict_score(x_test,y_test,x_train,y_train,C,sigma):
    model=SVC(C=C,kernel='rbf',gamma=sigma)
    model.fit(x_train,y_train)
    predictions=model.predict(x_test)
    print(">>>>>>>")
    print("Accuracy: C={} sigma={} is {}".format(C,sigma,metrics.accuracy_score(y_test,predictions)))
    print(">>>>>>>")

# %% [markdown]
# <h2>Hyperparameters</h2>

# %%
parameters={'C':C,'gamma':sigma,'kernel':['rbf']}
cols=X.columns
X=pd.DataFrame(scaler.fit_transform(X),columns=cols)
X.describe().apply(lambda s: s.apply('{0:.5f}'.format))
# Out:
#       Autocorrelation   Contrast Correlation Correlation.1 Cluster Prominence  \
# count       120.00000  120.00000   120.00000     120.00000          120.00000
# mean         -0.00000   -0.00000     0.00000       0.00000            0.00000
# std           1.00419    1.00419     1.00419       1.00419            1.00419
# min          -1.10782   -1.71325    -3.25142      -3.25142           -1.85066
# 25%          -0.84141   -0.72594    -0.71643      -0.71643           -0.71068
# 50%          -0.49025   -0.03014     0.29667       0.29667           -0.12936
# 75%           0.94049    0.73300     0.74875       0.74875            0.63854
# max           2.52279    2.59675     1.59095       1.59095            3.58591
#
#       Cluster Shade Dissimilarity     Energy    Entropy  Homogeneity  ...  \
# count     120.00000     120.00000  120.00000  120.00000    120.00000  ...
# mean       -0.00000      -0.00000   -0.00000   -0.00000      0.00000  ...
# ...

# %%
grid_s=GridSearchCV(SVC(),parameters,refit=True,verbose=3)
grid_s.fit(X,y)
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits
# [CV 1/5] END ....C=0.01, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 2/5] END ....C=0.01, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 3/5] END ....C=0.01, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 4/5] END ....C=0.01, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 5/5] END ....C=0.01, gamma=0.01, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 1/5] END ....C=0.01, gamma=0.03, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 2/5] END ....C=0.01, gamma=0.03, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 3/5] END ....C=0.01, gamma=0.03, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 4/5] END ....C=0.01, gamma=0.03, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 5/5] END ....C=0.01, gamma=0.03, kernel=rbf;, score=0.667 total time=   0.0s
# [CV 1/5] END .....C=0.01, gamma=0.1, kernel=rbf;, score=0.667 total time=   0.0s
# ...

# %%
print(grid_s.best_params_)
print(grid_s.best_estimator_)
# Out:
# {'C': 0.3, 'gamma': 0.03, 'kernel': 'rbf'}
# SVC(C=0.3, gamma=0.03)

# %%
#best c=0.3 , best gamma for this classification=0.03
model=SVC(C=0.3,gamma=0.03,kernel='rbf')
model.fit(X,y)
# Out:
# SVC(C=0.3, gamma=0.03)

# %% [markdown]
# <h2> Predictions</h2>

# %%
test_data=pd.read_csv('./Data/test_detection.csv')
test_data.head()
# Out:
#    Autocorrelation  Contrast  Correlation  Correlation.1  Cluster Prominence  \
# 0         4.937605  0.423813     0.894121       0.894121          231.248614
# 1         2.551722  0.259480     0.871947       0.871947          202.027005
# 2         6.206039  0.618669     0.881609       0.881609          290.479083
# 3         1.885596  0.194235     0.828962       0.828962           82.500028
# 4         4.790395  0.481035     0.890599       0.890599          343.387103
#
#    Cluster Shade  Dissimilarity    Energy   Entropy   Homogeneity  ...  \
# 0      32.252113       0.232233  0.518499  1.458699      0.907496  ...
# 1      25.453599       0.109989  0.813569  0.644821      0.961702  ...
# 2      38.493259       0.287417  0.465086  1.622099      0.893214  ...
# 3      12.126492       0.090015  0.849845  0.524957      0.967822  ...
# 4      44.837110       0.210380  0.629436  1.159005      0.925256  ...
#
#    Sum average  Sum variance  Sum entropy  Difference variance  \
# ...

# %%
test_data.describe()
# Out:
#        Autocorrelation    Contrast  Correlation  Correlation.1  \
# count       192.000000  192.000000   192.000000     192.000000
# mean          4.573637    0.268571     0.896885       0.896885
# std           3.147084    0.135100     0.043796       0.043796
# min           1.192696    0.038599     0.758959       0.758959
# 25%           2.105185    0.160458     0.865038       0.865038
# 50%           3.055012    0.262109     0.912535       0.912535
# 75%           7.483346    0.370147     0.930238       0.930238
# max          14.311495    0.618669     0.964613       0.964613
#
#        Cluster Prominence  Cluster Shade  Dissimilarity      Energy  \
# count          192.000000     192.000000     192.000000  192.000000
# mean           177.143063      19.952697       0.159041    0.632742
# std             81.769198       9.804233       0.097084    0.257692
# min             19.710267      -7.483682       0.018399    0.191741
# ...

# %%
y_test=test_data['class']
print(y_test.value_counts())
y_test.head()
# Out:
# 1    131
# 0     61
# Name: class, dtype: int64
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: class, dtype: int64

# %%
X_test=test_data.drop(labels="class",axis=1)
print(X_test.shape)
X_test.head()
# Out:
# (192, 22)
#    Autocorrelation  Contrast  Correlation  Correlation.1  Cluster Prominence  \
# 0         4.937605  0.423813     0.894121       0.894121          231.248614
# 1         2.551722  0.259480     0.871947       0.871947          202.027005
# 2         6.206039  0.618669     0.881609       0.881609          290.479083
# 3         1.885596  0.194235     0.828962       0.828962           82.500028
# 4         4.790395  0.481035     0.890599       0.890599          343.387103
#
#    Cluster Shade  Dissimilarity    Energy   Entropy   Homogeneity  ...  \
# 0      32.252113       0.232233  0.518499  1.458699      0.907496  ...
# 1      25.453599       0.109989  0.813569  0.644821      0.961702  ...
# 2      38.493259       0.287417  0.465086  1.622099      0.893214  ...
# 3      12.126492       0.090015  0.849845  0.524957      0.967822  ...
# 4      44.837110       0.210380  0.629436  1.159005      0.925256  ...
#
# ...

# %%
#making predictions
cols=X_test.columns
X_test=pd.DataFrame(scaler.fit_transform(X_test),columns=cols)
predictions=model.predict(X_test)
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        61
#            1       1.00      1.00      1.00       131
#
#     accuracy                           1.00       192
#    macro avg       1.00      1.00      1.00       192
# weighted avg       1.00      1.00      1.00       192

# %% [markdown]
# <h2>Confusion Matrix</h2>

# %%
matrix=confusion_matrix(y_test,predictions)
cm_df=pd.DataFrame(matrix,index=["Healthy","Diseased"],columns=["Healthy","Diseased"])
plt.xlabel("")
sns.heatmap(cm_df,annot_kws={"size": 16},annot=True,fmt="d")
# Out:
# <AxesSubplot:>

# %% [markdown]
# <h2>ROC Curve</h2>

# %%
fp_rate,tp_rate,threshold=roc_curve(y_test,predictions)
print("roc auc score is : {}".format(roc_auc_score(y_test,predictions)))
# Out:
# roc auc score is : 1.0

# %%
plt.title('Roc curve for SVM classifier C=0.03 gamma=0.03')
plt.plot(fp_rate,tp_rate)
plt.plot([0, 1], ls="--")
plt.plot([0, 0], [1, 0] , c=".7")
plt.plot([1, 1] , c=".7")
plt.ylabel("True positive rate")
plt.xlabel("False positive rate")
# Out:
# Text(0.5, 0, 'False positive rate')
