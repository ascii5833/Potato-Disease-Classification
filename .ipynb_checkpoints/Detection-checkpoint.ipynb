# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn import metrics
# %matplotlib inline

# %%
#read detection dataframe
df=pd.read_csv("Data/train_detection.csv")
df.head()
# Out:
#    Autocorrelation  Contrast  Correlation  Correlation.1  Cluster Prominence  \
# 0         4.937605  0.423813     0.894121       0.894121          231.248614
# 1         2.551722  0.259480     0.871947       0.871947          202.027005
# 2         6.206039  0.618669     0.881609       0.881609          290.479083
# 3         1.885596  0.194235     0.828962       0.828962           82.500028
# 4         4.790395  0.481035     0.890599       0.890599          343.387103
#
#    Cluster Shade  Dissimilarity    Energy   Entropy   Homogeneity  ...  \
# 0      32.252113       0.232233  0.518499  1.458699      0.907496  ...
# 1      25.453599       0.109989  0.813569  0.644821      0.961702  ...
# 2      38.493259       0.287417  0.465086  1.622099      0.893214  ...
# 3      12.126492       0.090015  0.849845  0.524957      0.967822  ...
# 4      44.837110       0.210380  0.629436  1.159005      0.925256  ...
#
#    Sum average  Sum variance  Sum entropy  Difference variance  \
# ...

# %%
#extract the target feature
y=df['class']
X=df.drop(labels="class",axis=1)
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: class, dtype: int64

# %%
X.head()
# Out:
#    Autocorrelation  Contrast  Correlation  Correlation.1  Cluster Prominence  \
# 0         4.937605  0.423813     0.894121       0.894121          231.248614
# 1         2.551722  0.259480     0.871947       0.871947          202.027005
# 2         6.206039  0.618669     0.881609       0.881609          290.479083
# 3         1.885596  0.194235     0.828962       0.828962           82.500028
# 4         4.790395  0.481035     0.890599       0.890599          343.387103
#
#    Cluster Shade  Dissimilarity    Energy   Entropy   Homogeneity  ...  \
# 0      32.252113       0.232233  0.518499  1.458699      0.907496  ...
# 1      25.453599       0.109989  0.813569  0.644821      0.961702  ...
# 2      38.493259       0.287417  0.465086  1.622099      0.893214  ...
# 3      12.126492       0.090015  0.849845  0.524957      0.967822  ...
# 4      44.837110       0.210380  0.629436  1.159005      0.925256  ...
#
#    Sum of sqaures: Variance  Sum average  Sum variance  Sum entropy  \
# ...

# %%
#divide data into training and validation data
X_train,X_val,y_train,y_val=train_test_split(X,y,test_size=0.2)
X_train.head()
# Out:
#      Autocorrelation  Contrast  Correlation  Correlation.1  \
# 8           1.755978  0.160803     0.849473       0.849473
# 76          3.083565  0.171906     0.932120       0.932120
# 9           2.109007  0.240043     0.837149       0.837149
# 16          1.549803  0.152416     0.806465       0.806465
# 110         6.917834  0.288524     0.927513       0.927513
#
#      Cluster Prominence  Cluster Shade  Dissimilarity    Energy   Entropy  \
# 8            119.458388      14.607776       0.061517  0.911256  0.337693
# 76           240.431281      31.113137       0.099589  0.773229  0.739599
# 9            127.086262      17.236127       0.100971  0.846573  0.542582
# 16            83.783393      10.297439       0.056218  0.916714  0.319897
# 110           94.199686       9.258885       0.234436  0.297486  1.798563
#
#       Homogeneity  ...  Sum of sqaures: Variance  Sum average  Sum variance  \
# 8        0.980038  ...                  1.800960     2.282477      5.947551
# ...

# %%
print(y_train.value_counts())
print(y_val.value_counts())
y_train.head()
# Out:
# 1    62
# 0    34
# Name: class, dtype: int64
# 1    18
# 0     6
# Name: class, dtype: int64
# 8      0
# 76     1
# 9      0
# 16     0
# 110    1
# Name: class, dtype: int64

# %%
#choosing different C values
C=[0.01,0.03,0.1,0.3,1,3,10,30,100]
sigma=[0.01,0.03,0.1,0.3,1,3,10,30,100]

# %%
#predict score function
def predict_score(x_test,y_test,x_train,y_train,C,sigma):
    model=SVC(C=C,kernel='rbf',gamma=sigma)
    model.fit(x_train,y_train)
    predictions=model.predict(x_test)
    print(">>>>>>>")
    print("Accuracy: C={} sigma={} is {}".format(C,sigma,metrics.accuracy_score(y_test,predictions)))
    print(">>>>>>>")

# %% [markdown]
# <h2>Error Metrics</h2>

# %%
#calculate scores
for c_val in C:
    for sigma_val in sigma:
        predict_score(X_val,y_val,X_train,y_train,c_val,sigma_val)
# Out:
# >>>>>>>
# Accuracy: C=0.01 sigma=0.01 is 0.75
# >>>>>>>
# >>>>>>>
# Accuracy: C=0.01 sigma=0.03 is 0.75
# >>>>>>>
# >>>>>>>
# Accuracy: C=0.01 sigma=0.1 is 0.75
# >>>>>>>
# >>>>>>>
# Accuracy: C=0.01 sigma=0.3 is 0.75
# >>>>>>>
# >>>>>>>
# Accuracy: C=0.01 sigma=1 is 0.75
# >>>>>>>
# >>>>>>>
# Accuracy: C=0.01 sigma=3 is 0.75
# >>>>>>>
# >>>>>>>
# Accuracy: C=0.01 sigma=10 is 0.75
# >>>>>>>
# >>>>>>>
# Accuracy: C=0.01 sigma=30 is 0.75
# >>>>>>>
# >>>>>>>
# Accuracy: C=0.01 sigma=100 is 0.75
# >>>>>>>
# >>>>>>>
# Accuracy: C=0.03 sigma=0.01 is 0.75
# >>>>>>>
# >>>>>>>
# Accuracy: C=0.03 sigma=0.03 is 0.75
# >>>>>>>
# >>>>>>>
# Accuracy: C=0.03 sigma=0.1 is 0.75
# >>>>>>>
# >>>>>>>
# Accuracy: C=0.03 sigma=0.3 is 0.75
# >>>>>>>
# >>>>>>>
# Accuracy: C=0.03 sigma=1 is 0.75
# >>>>>>>
# >>>>>>>
# Accuracy: C=0.03 sigma=3 is 0.75
# >>>>>>>
# >>>>>>>
# Accuracy: C=0.03 sigma=10 is 0.75
# >>>>>>>
# >>>>>>>
# Accuracy: C=0.03 sigma=30 is 0.75
# >>>>>>>
# >>>>>>>
# ...

# %%
#so, at C=30 and sigma =1 and C=100 and sigma=0.03 , we get 91.66 percent accuracy for rbf kernel
